# %% [markdown]
# <a href="https://colab.research.google.com/github/samcastroca/proyecto-pdi/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hola')
# Out:
# hola
